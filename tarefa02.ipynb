# %% [markdown]
# <a href="https://colab.research.google.com/github/annebrazao1519-art/Aula-1-Bioestat-stica-/blob/main/tarefa02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 02
#
# #Grupo:
# ##Raianne Brazão 16898499
# ##Tiago Monteiro 16991607
# ##Vitória Ortiz 16904821

# %%
import pandas as pd

df = pd.read_excel("/content/tarefa02.xlsx")

# %%
df
# Out:
#               Árvore  Tamanho (m)  Idade (anos)
# 0           Ipê-roxo         12.5            15
# 1          Jequitibá         35.0            85
# 2           Gabiroba          3.2             6
# 3         Pau-mulato         22.0            45
# 4           Sapucaia         28.5            60
# 5      Jabuticabeira          4.5            12
# 6        Pitangueira          2.8             8
# 7            Acerola          2.1             5
# 8            Jussara          8.0            20
# 9             Jerivá         10.5            25
# 10            Imbuia         25.0            70
# 11  Canela-sassafras         18.0            50
# 12             Cedro         30.0            75
# 13             Mogno         27.5            65
# 14          Magnolia          6.0            14
# 15         Jacarandá         15.0            35
# 16          Andiroba         24.0            55
# 17             Araçá          3.5             7
# 18            Jatobá         32.0            80
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ler a tabela
dados = pd.read_excel("tarefa02.xlsx")

# Criar as faixas de idade
faixas = pd.cut(
    dados["Idade (anos)"],
    bins=[0, 8, 16, 25, float("inf")],
    labels=["0–8 anos", "9–16 anos", "17–25 anos", "26+ anos"]
)

# Contar quantas árvores existem em cada faixa
quantidade = faixas.value_counts().sort_index()

# Criar o gráfico
plt.figure(figsize=(9, 7))

fatias, textos, porcentagens = plt.pie(
    quantidade,
    autopct="%1.1f%%",
    startangle=90
)

# Criar os textos da legenda
legenda = [
    f"{faixa} — {qtd} árvores"
    for faixa, qtd in zip(quantidade.index, quantidade)
]

# Criar a legenda
plt.legend(
    fatias,
    legenda,
    title="Faixa de idade",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title(
    "Distribuição das árvores por faixa etária",
    fontsize=16,
    fontweight="bold"
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel("tarefa02.xlsx")

plt.figure(figsize=(10, 6))

plt.scatter(
    df['Idade (anos)'],
     df['Tamanho (m)'],
    color='forestgreen',
    edgecolor='black'
)

plt.title(
    'Relação entre Tamanho e Idade das Árvores',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('Idade (anos)', fontsize=12)
plt.ylabel('Tamanho (m)', fontsize=12)

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))

df.boxplot(
    column='Tamanho (m)')

plt.title('média do tamanho das Espécies')
plt.ylabel('Tamanho (m)')
plt.xlabel('') # Define o rótulo do eixo X como espécie

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(
    df['Idade (anos)'].dropna(),
    bins=8,
    color='forestgreen',
    edgecolor='black'
)

plt.title(
    'Distribuição da Idade das Árvores',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('Idade (anos)', fontsize=12)
plt.ylabel('Quantidade de Árvores', fontsize=12)

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
